# %%
import gurobipy as gp
from gurobipy import GRB
from pathlib import Path
import os
import numpy as np
import sys
import random as rd

# %%
INSTANCE_PATH = Path('../instances/sifaleras')
RESULT_PATH   = Path('../RESULTADOS/')

# %%
def leitura_instance(file_name):
    arq = open(os.path.join(INSTANCE_PATH,file_name))
    N = int(arq.readline())
    PP  = [0]*N
    PR  = [0]*N

    FP = [float(arq.readline())]*N
    FR = [float(arq.readline())]*N

    HR = [float(arq.readline())]*N
    HP = [float(arq.readline())]*N

    D = [int(i) for i in arq.readline().split()]
    
    R = [int(i) for i in arq.readline().split()]
    
    return N, PP, PR, FP, FR, HR, HP, D, R

# %%
cap = True
file_name = '52_1.txt' #sys.argv[1]
N, PP, PR, FP, FR, HR, HP, D, R =leitura_instance(file_name)
MAX_CPU_TIME = 600.0
EPSILON = 0.000001

# %%
SD = (np.zeros((N,N))).tolist()
SR = (np.zeros((N,N))).tolist()
for  i in range(N):
    SD[i][i] = D[i]
    SR[i][i] = R[i]
    for j in range(i+1, N):
        SD[i][j] = SD[i][j-1] + D[j]
        SR[i][j] = SR[i][j-1] + R[j]
    
soma = sum(D)
fator = 1.5
#Capacidade de cada período
C = (soma * fator)/N

# %%
# _lambda = 0.95
# C = _lambda*max(R) + (1-_lambda)*sum(R)
# C

# %%
def relax_fix(particoes,yp_sol ,yr_sol):
    try:

        # Create a new model
        model = gp.Model("CLSR")

        # Create variables
        
        xp = model.addVars(list(range(N)), lb =0.0, ub = float('inf'),vtype=GRB.CONTINUOUS, name="xp")
        yp = model.addVars(list(range(N)), lb =0.0, ub = 1.0,vtype=GRB.BINARY, name="yp")
        sp = model.addVars(list(range(N)), lb =0.0, ub = float('inf'),vtype=GRB.CONTINUOUS, name="sp")
        xr = model.addVars(list(range(N)), lb =0.0, ub = float('inf'),vtype=GRB.CONTINUOUS, name="xr")
        yr = model.addVars(list(range(N)), lb =0.0, ub = 1.0,vtype=GRB.BINARY, name="yr")
        sr = model.addVars(list(range(N)), lb =0.0, ub = float('inf'),vtype=GRB.CONTINUOUS, name="sr")
        
        for i in range(N):
            if i > max(particoes) :
                yp[i].VType = gp.GRB.CONTINUOUS
                yp[i].lb    = 0
                yp[i].ub    = 1
                yr[i].VType = gp.GRB.CONTINUOUS
                yr[i].lb    = 0
                yr[i].ub    = 1
            elif i in particoes:
                yp[i].lb = 0
                yp[i].ub = 1
                yr[i].lb = 0
                yr[i].ub = 1
            else:
                yp[i].lb = yp_sol[i]
                yp[i].ub = yp_sol[i]
                yr[i].lb = yr_sol[i]
                yr[i].ub = yr_sol[i]

        
        model.update()

        # # Set objective
        model.setObjective(gp.quicksum(PP[i]*xp[i]+sp[i]*HP[i] + xr[i]*PR[i] + sr[i]*HR[i] + yp[i]*FP[i] + yr[i]*FR[i] for i in range(N)) , sense = GRB.MINIMIZE)

        # # Add constraints
        
        model.addConstr(xp[0]+xr[0]-sp[0] == D[0])
        model.addConstrs(sp[i-1] + xp[i] + xr[i] - sp[i] == D[i] for i in range(N) if i > 0 )
        model.addConstr(R[0] - xr[0] - sr[0] == 0)
        model.addConstrs(sr[i-1] + R[i] - xr[i] - sr[i] == 0 for i in range(N) if i > 0)
        model.addConstrs(xp[i] - yp[i]*min(C,SD[i][N-1]) <= 0 for i in range(N))
        model.addConstrs(xr[i] - yr[i]*min(SR[0][i], SD[i][N-1]) <= 0 for i in range(N))
        model.addConstrs(xp[i] + xr[i] <= C for i in range(N))

        
        model.write(file_name+".lp")

        # Parameters 
        model.setParam(GRB.Param.TimeLimit, MAX_CPU_TIME)
        model.setParam(GRB.Param.MIPGap, EPSILON)
        model.setParam(GRB.Param.Threads,1)
        model.setParam(GRB.Param.Cuts, -1)
        model.setParam(GRB.Param.Presolve,-1)


        # Optimize model
        model.optimize()
        
        
        xp_sol = [xp[i].X for i in range(N)]
        xr_sol = [xr[i].X for i in range(N)]
        sp_sol = [sp[i].X for i in range(N)]
        sr_sol = [sr[i].X for i in range(N)]
        yp_sol = [yp[i].X for i in range(N)]
        yr_sol = [yr[i].X for i in range(N)]


        print('Obj: %g' % model.ObjVal)

    except gp.GurobiError as e:
        print('Error code ' + str(e.errno) + ': ' + str(e))

    except AttributeError:
        print('Encountered an attribute error')

    return model.ObjVal, xp_sol,xr_sol,sp_sol,sr_sol, yp_sol,yr_sol

# %%
def gera_particoes(tamanho_particao=2):
    subset = []

    tam_subset = tamanho_particao

    for i in range(0,N,tam_subset):
        if i + tam_subset > N:
            subset.append([k for k in range(i,N)])
        else:
            subset.append([k for k in range(i,i+tam_subset)])
    return subset

# %%
def fix_and_optimize(particoes,yp_sol,yr_sol):
    indices = particoes.copy()
 #   for  i in range(len(particoes)):
 #       for j in range(len(particoes[i])):
 #           indices.append(j)
    try:

        # Create a new model
        model = gp.Model("CLSR")

        # Create variables
    
        xp = model.addVars(list(range(N)), lb =0.0, ub = float('inf'),vtype=GRB.CONTINUOUS, name="xp")
        yp = model.addVars(list(range(N)), lb =0.0, ub = 1.0,vtype=GRB.BINARY, name="yp")
        sp = model.addVars(list(range(N)), lb =0.0, ub = float('inf'),vtype=GRB.CONTINUOUS, name="sp")
        xr = model.addVars(list(range(N)), lb =0.0, ub = float('inf'),vtype=GRB.CONTINUOUS, name="xr")
        yr = model.addVars(list(range(N)), lb =0.0, ub = 1.0,vtype=GRB.BINARY, name="yr")
        sr = model.addVars(list(range(N)), lb =0.0, ub = float('inf'),vtype=GRB.CONTINUOUS, name="sr")

      
        for i in range(N):
            if i in indices:
                yp[i].lb    = 0
                yp[i].ub    = 1
                yr[i].lb    = 0
                yr[i].ub    = 1
            else:
                yp[i].lb    = yp_sol[i]
                yp[i].ub    = yp_sol[i]
                yr[i].lb    = yr_sol[i]
                yr[i].ub    = yr_sol[i]
        
        model.update()
        # # Set objective
        model.setObjective(gp.quicksum(PP[i]*xp[i]+sp[i]*HP[i] + xr[i]*PR[i] + sr[i]*HR[i] + yp[i]*FP[i] + yr[i]*FR[i] for i in range(N)) , sense = GRB.MINIMIZE)

        # # Add constraints
    
        model.addConstr(xp[0]+xr[0]-sp[0] == D[0])
        model.addConstrs(sp[i-1] + xp[i] + xr[i] - sp[i] == D[i] for i in range(N) if i > 0 )
        model.addConstr(R[0] - xr[0] - sr[0] == 0)
        model.addConstrs(sr[i-1] + R[i] - xr[i] - sr[i] == 0 for i in range(N) if i > 0)
        model.addConstrs(xp[i] - yp[i]*min(C,SD[i][N-1]) <= 0 for i in range(N))
        model.addConstrs(xr[i] - yr[i]*min(SR[0][i], SD[i][N-1]) <= 0 for i in range(N))
        model.addConstrs(xp[i] + xr[i] <= C for i in range(N))
        model.write(file_name+"_model.lp")

        # Parameters 
        model.setParam(GRB.Param.TimeLimit, MAX_CPU_TIME)
        model.setParam(GRB.Param.MIPGap, EPSILON)
        model.setParam(GRB.Param.Threads,1)
        model.setParam(GRB.Param.Cuts, -1)
        model.setParam(GRB.Param.Presolve,-1)



        # Optimize model
        model.optimize()

        xp_sol = [xp[i].X for i in range(N)]
        xr_sol = [xr[i].X for i in range(N)]
        sp_sol = [sp[i].X for i in range(N)]
        sr_sol = [sr[i].X for i in range(N)]
        yp_sol = [yp[i].X for i in range(N)]
        yr_sol = [yr[i].X for i in range(N)]




        print('Obj: %g' % model.ObjVal)

    except gp.GurobiError as e:
        print('Error code ' + str(e.errno) + ': ' + str(e))

    return model.ObjVal, xp_sol,xr_sol,sp_sol,sr_sol, yp_sol,yr_sol

# %%
tam_sort = rd.randint(1,10)
tam_sort
# Out:
# 7

# %%
def heuristic():
    obj = 0
    xp_sol = [0]*N
    xr_sol = [0]*N
    sp_sol = [0]*N
    sr_sol = [0]*N
    yp_sol = [0]*N
    yr_sol = [0]*N
    

    subset = gera_particoes()
    for particao in subset:
        obj,xp_sol,xr_sol,sp_sol,sr_sol, yp_sol,yr_sol = relax_fix(particao,yp_sol,yr_sol)
    
    for particao in subset:
        obj,xp_sol,xr_sol,sp_sol,sr_sol, yp_sol,yr_sol = fix_and_optimize(particao,yp_sol,yr_sol)
    
    obj_    = obj
    xp_sol_ = xp_sol.copy()
    xr_sol_ = xr_sol.copy()
    sp_sol_ = sp_sol.copy()
    sr_sol_ = sr_sol.copy()
    yp_sol_ = yp_sol.copy()
    yr_sol_ = yr_sol.copy()


    
    for cont in range(30):
        tam_sort = rd.randint(1,10)
        subset = gera_particoes(tam_sort)
        part_sort = rd.randint(0,len(subset)-1)

        obj_,xp_sol_,xr_sol_,sp_sol_,sr_sol_, yp_sol_,yr_sol_ = fix_and_optimize(subset[part_sort],yp_sol_,yr_sol_)

        if obj_ < obj :
            obj = obj_
            xp_sol = xp_sol_.copy()
            xr_sol = xr_sol_.copy()
            sp_sol = sp_sol_.copy()
            sr_sol = sr_sol_.copy()
            yp_sol = yp_sol_.copy()
            yr_sol = yr_sol_.copy()
    

    return obj,xp_sol,xr_sol, sp_sol,sr_sol, yp_sol,yr_sol

# %%
obj,xp_sol,xr_sol, sp_sol,sr_sol, yp_sol,yr_sol = heuristic()
# Out:
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xd0740ed9
# Variable types: 308 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 107 rows and 107 columns
# Presolve time: 0.00s
# Presolved: 153 rows, 205 columns, 455 nonzeros
# Variable types: 203 continuous, 2 integer (2 binary)
# Found heuristic solution: objective 6322.1128649
#
# Root relaxation: objective 5.959694e+03, 142 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5959.6942964 5959.69430  0.00%     -    0s
#
# Explored 1 nodes (142 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 5959.69 6322.11
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 5.959694296382e+03, best bound 5.959694296382e+03, gap 0.0000%
# Obj: 5959.69
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xf9265cfb
# Variable types: 304 continuous, 8 integer (8 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 107 rows and 109 columns
# Presolve time: 0.00s
# Presolved: 153 rows, 203 columns, 455 nonzeros
# Variable types: 199 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 6424.9178156
#
# Root relaxation: objective 5.959694e+03, 142 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5959.69430    0    2 6424.91782 5959.69430  7.24%     -    0s
# H    0     0                    6132.3062126 5959.69430  2.81%     -    0s
# H    0     0                    6036.7423423 5959.69430  1.28%     -    0s
#      0     0     cutoff    0      6036.74234 6036.74234  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 1
#   Flow cover: 4
#
# Explored 1 nodes (144 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6036.74 6132.31 6424.92
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 6.036742342338e+03, best bound 6.036742342338e+03, gap 0.0000%
# Obj: 6036.74
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x863f2721
# Variable types: 300 continuous, 12 integer (12 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 113 rows and 117 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 195 columns, 437 nonzeros
# Variable types: 191 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 6292.0954201
#
# Root relaxation: objective 6.036742e+03, 137 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6036.74234    0    3 6292.09542 6036.74234  4.06%     -    0s
# H    0     0                    6122.0472337 6036.74234  1.39%     -    0s
# H    0     0                    6115.9492631 6036.74234  1.30%     -    0s
#      0     0 6092.79000    0    4 6115.94926 6092.79000  0.38%     -    0s
# H    0     0                    6092.8549527 6092.79000  0.00%     -    0s
#
# Cutting planes:
#   Cover: 2
#   Implied bound: 1
#   Clique: 1
#   Flow cover: 1
#
# Explored 1 nodes (146 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 6092.85 6115.95 6122.05 6292.1
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 6.092854952699e+03, best bound 6.092854952699e+03, gap 0.0000%
# Obj: 6092.85
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xdd0a0bc9
# Variable types: 296 continuous, 16 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 116 rows and 121 columns
# Presolve time: 0.00s
# Presolved: 144 rows, 191 columns, 427 nonzeros
# Variable types: 187 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 6423.0545990
#
# Root relaxation: objective 6.106150e+03, 135 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6106.15031    0    2 6423.05460 6106.15031  4.93%     -    0s
# H    0     0                    6257.3258297 6106.15031  2.42%     -    0s
#      0     0 6187.36689    0    1 6257.32583 6187.36689  1.12%     -    0s
#      0     0 6213.30989    0    4 6257.32583 6213.30989  0.70%     -    0s
#      0     0 6219.60410    0    2 6257.32583 6219.60410  0.60%     -    0s
#      0     0 6225.43556    0    1 6257.32583 6225.43556  0.51%     -    0s
# *    0     0               0    6226.6681255 6226.66813  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   Implied bound: 3
#   Flow cover: 4
#   Relax-and-lift: 1
#
# Explored 1 nodes (152 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 6226.67 6423.05
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 6.226668125548e+03, best bound 6.226668125548e+03, gap 0.0000%
# Obj: 6226.67
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x0a0d801c
# Variable types: 292 continuous, 20 integer (20 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 120 rows and 126 columns
# Presolve time: 0.00s
# Presolved: 140 rows, 186 columns, 412 nonzeros
# Variable types: 182 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 6595.7982544
#
# Root relaxation: objective 6.255176e+03, 127 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6255.17601    0    2 6595.79825 6255.17601  5.16%     -    0s
# H    0     0                    6449.2243183 6255.17601  3.01%     -    0s
# H    0     0                    6336.1433166 6255.17601  1.28%     -    0s
#      0     0     cutoff    0      6336.14332 6336.14332  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 2
#   Flow cover: 3
#
# Explored 1 nodes (131 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6336.14 6449.22 6595.8
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 6.336143316617e+03, best bound 6.336143316617e+03, gap 0.0000%
# Obj: 6336.14
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x4fbc61df
# Variable types: 288 continuous, 24 integer (24 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 127 rows and 136 columns
# Presolve time: 0.00s
# Presolved: 133 rows, 176 columns, 391 nonzeros
# Variable types: 172 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 6737.0640310
#
# Root relaxation: objective 6.403051e+03, 116 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6403.05141    0    3 6737.06403 6403.05141  4.96%     -    0s
# H    0     0                    6539.2643509 6403.05141  2.08%     -    0s
#      0     0 6498.45670    0    3 6539.26435 6498.45670  0.62%     -    0s
#      0     0 6502.08596    0    2 6539.26435 6502.08596  0.57%     -    0s
#      0     0 6504.98091    0    4 6539.26435 6504.98091  0.52%     -    0s
#      0     0 6505.85672    0    1 6539.26435 6505.85672  0.51%     -    0s
#      0     0 6514.62846    0    3 6539.26435 6514.62846  0.38%     -    0s
# H    0     0                    6539.1151860 6514.62846  0.37%     -    0s
#      0     0 6516.15409    0    3 6539.11519 6516.15409  0.35%     -    0s
#      0     0 6521.43760    0    3 6539.11519 6521.43760  0.27%     -    0s
#      0     0 6521.44054    0    3 6539.11519 6521.44054  0.27%     -    0s
#      0     0 6537.98168    0    2 6539.11519 6537.98168  0.02%     -    0s
#      0     0     cutoff    0      6539.11519 6539.11519  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 2
#   MIR: 3
#   Flow cover: 5
#
# Explored 1 nodes (152 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6539.12 6539.26 6737.06
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 6.539115186016e+03, best bound 6.539115186016e+03, gap 0.0000%
# Obj: 6539.12
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xf43de11c
# Variable types: 284 continuous, 28 integer (28 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 130 rows and 139 columns
# Presolve time: 0.00s
# Presolved: 130 rows, 173 columns, 382 nonzeros
# Variable types: 169 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 6766.6871254
#
# Root relaxation: objective 6.578441e+03, 116 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6578.44098    0    2 6766.68713 6578.44098  2.78%     -    0s
# H    0     0                    6681.1737685 6578.44098  1.54%     -    0s
#      0     0 6665.03767    0    1 6681.17377 6665.03767  0.24%     -    0s
# H    0     0                    6670.8043819 6665.03767  0.09%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 1
#   Flow cover: 2
#
# Explored 1 nodes (121 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6670.8 6681.17 6766.69
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 6.670804381875e+03, best bound 6.670804381875e+03, gap 0.0000%
# Obj: 6670.8
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x695cbaff
# Variable types: 280 continuous, 32 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 136 rows and 146 columns
# Presolve time: 0.00s
# Presolved: 124 rows, 166 columns, 365 nonzeros
# Variable types: 162 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 7094.5217181
#
# Root relaxation: objective 6.767836e+03, 115 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6767.83573    0    3 7094.52172 6767.83573  4.60%     -    0s
# H    0     0                    6895.0002223 6767.83573  1.84%     -    0s
#      0     0 6849.50984    0    1 6895.00022 6849.50984  0.66%     -    0s
#      0     0     cutoff    0      6895.00022 6895.00022  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 3
#   StrongCG: 1
#   Flow cover: 5
#
# Explored 1 nodes (123 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 6895 7094.52
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 6.895000222281e+03, best bound 6.895000222281e+03, gap 0.0000%
# Obj: 6895
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x5bc7e4fa
# Variable types: 276 continuous, 36 integer (36 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 141 rows and 151 columns
# Presolve time: 0.00s
# Presolved: 119 rows, 161 columns, 351 nonzeros
# Variable types: 157 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 7156.5816389
#
# Root relaxation: objective 6.993414e+03, 104 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6993.41443    0    2 7156.58164 6993.41443  2.28%     -    0s
# H    0     0                    7098.3027928 6993.41443  1.48%     -    0s
#      0     0 7090.19226    0    1 7098.30279 7090.19226  0.11%     -    0s
# H    0     0                    7090.3027928 7090.19226  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 1
#   Flow cover: 2
#
# Explored 1 nodes (107 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 7090.3 7098.3 7156.58
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 7.090302792791e+03, best bound 7.090302792791e+03, gap 0.0000%
# Obj: 7090.3
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xaf6097c1
# Variable types: 272 continuous, 40 integer (40 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 147 rows and 158 columns
# Presolve time: 0.00s
# Presolved: 113 rows, 154 columns, 334 nonzeros
# Variable types: 150 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 7560.0695565
#
# Root relaxation: objective 7.222665e+03, 100 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7222.66537    0    3 7560.06956 7222.66537  4.46%     -    0s
# H    0     0                    7361.9734177 7222.66537  1.89%     -    0s
#      0     0 7308.86237    0    1 7361.97342 7308.86237  0.72%     -    0s
#      0     0 7330.83877    0    3 7361.97342 7330.83877  0.42%     -    0s
#      0     0 7330.92935    0    4 7361.97342 7330.92935  0.42%     -    0s
#      0     0 7343.61303    0    4 7361.97342 7343.61303  0.25%     -    0s
#      0     0     cutoff    0      7361.97342 7361.97342  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 3
#   StrongCG: 1
#   Flow cover: 5
#
# Explored 1 nodes (121 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 7361.97 7560.07
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 7.361973417669e+03, best bound 7.361973417669e+03, gap 0.0000%
# Obj: 7361.97
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xd2eb910e
# Variable types: 268 continuous, 44 integer (44 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 152 rows and 163 columns
# Presolve time: 0.00s
# Presolved: 108 rows, 149 columns, 320 nonzeros
# Variable types: 145 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 7859.1865392
#
# Root relaxation: objective 7.508855e+03, 90 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7508.85514    0    2 7859.18654 7508.85514  4.46%     -    0s
# H    0     0                    7709.6023212 7508.85514  2.60%     -    0s
# H    0     0                    7630.2617139 7508.85514  1.59%     -    0s
#      0     0 7599.90769    0    2 7630.26171 7599.90769  0.40%     -    0s
# H    0     0                    7606.7518963 7599.90769  0.09%     -    0s
#      0     0     cutoff    0      7606.75190 7606.75190  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 1
#   Flow cover: 2
#
# Explored 1 nodes (96 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 7606.75 7630.26 7709.6 7859.19
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 7.606751896278e+03, best bound 7.606751896278e+03, gap 0.0000%
# Obj: 7606.75
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xd6104019
# Variable types: 264 continuous, 48 integer (48 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 157 rows and 169 columns
# Presolve time: 0.00s
# Presolved: 103 rows, 143 columns, 306 nonzeros
# Variable types: 139 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 8075.2308762
#
# Root relaxation: objective 7.727108e+03, 86 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7727.10849    0    3 8075.23088 7727.10849  4.31%     -    0s
# H    0     0                    7876.1405365 7727.10849  1.89%     -    0s
#      0     0 7813.80482    0    1 7876.14054 7813.80482  0.79%     -    0s
#      0     0 7842.94929    0    4 7876.14054 7842.94929  0.42%     -    0s
#      0     0 7852.72934    0    4 7876.14054 7852.72934  0.30%     -    0s
#      0     0 7858.13739    0    3 7876.14054 7858.13739  0.23%     -    0s
#      0     0 7862.73356    0    4 7876.14054 7862.73356  0.17%     -    0s
#      0     0 7866.23754    0    4 7876.14054 7866.23754  0.13%     -    0s
#      0     0 7866.72557    0    4 7876.14054 7866.72557  0.12%     -    0s
#      0     0     cutoff    0      7876.14054 7876.14054  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   MIR: 5
#   StrongCG: 1
#   Flow cover: 7
#
# Explored 1 nodes (123 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 7876.14 8075.23
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 7.876140536510e+03, best bound 7.876140536510e+03, gap 0.0000%
# Obj: 7876.14
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x52901d04
# Variable types: 260 continuous, 52 integer (52 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 162 rows and 174 columns
# Presolve time: 0.00s
# Presolved: 98 rows, 138 columns, 292 nonzeros
# Variable types: 134 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 8378.3465684
#
# Root relaxation: objective 8.010200e+03, 80 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8010.19982    0    2 8378.34657 8010.19982  4.39%     -    0s
# H    0     0                    8235.0629461 8010.19982  2.73%     -    0s
# H    0     0                    8132.7774041 8010.19982  1.51%     -    0s
#      0     0 8098.34393    0    2 8132.77740 8098.34393  0.42%     -    0s
# H    0     0                    8116.4417232 8098.34393  0.22%     -    0s
# *    0     0               0    8104.7774041 8104.77740  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 4
#   Flow cover: 5
#
# Explored 1 nodes (87 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 5: 8104.78 8116.44 8132.78 ... 8378.35
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 8.104777404119e+03, best bound 8.104777404119e+03, gap 0.0000%
# Obj: 8104.78
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xd45a7288
# Variable types: 256 continuous, 56 integer (56 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 168 rows and 181 columns
# Presolve time: 0.00s
# Presolved: 92 rows, 131 columns, 275 nonzeros
# Variable types: 127 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 8632.7890953
#
# Root relaxation: objective 8.260551e+03, 76 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8260.55077    0    3 8632.78910 8260.55077  4.31%     -    0s
# H    0     0                    8433.0859434 8260.55077  2.05%     -    0s
#      0     0 8350.01068    0    3 8433.08594 8350.01068  0.99%     -    0s
# H    0     0                    8385.6351938 8350.01068  0.42%     -    0s
# *    0     0               0    8382.0607015 8382.06070  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 4
#   Flow cover: 6
#
# Explored 1 nodes (93 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 8382.06 8385.64 8433.09 8632.79
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 8.382060701545e+03, best bound 8.382060701545e+03, gap 0.0000%
# Obj: 8382.06
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xb03905dd
# Variable types: 252 continuous, 60 integer (60 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 174 rows and 188 columns
# Presolve time: 0.00s
# Presolved: 86 rows, 124 columns, 259 nonzeros
# Variable types: 120 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 8658.2929220
#
# Root relaxation: objective 8.516869e+03, 71 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8516.86941    0    2 8658.29292 8516.86941  1.63%     -    0s
#      0     0 8606.73705    0    1 8658.29292 8606.73705  0.60%     -    0s
#      0     0 8623.17062    0    3 8658.29292 8623.17062  0.41%     -    0s
#      0     0     cutoff    0      8658.29292 8658.29292  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Clique: 1
#   MIR: 2
#   Flow cover: 4
#
# Explored 1 nodes (84 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 8658.29
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 8.658292921978e+03, best bound 8.658292921978e+03, gap 0.0000%
# Obj: 8658.29
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xa5ffa4ad
# Variable types: 248 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 179 rows and 193 columns
# Presolve time: 0.00s
# Presolved: 81 rows, 119 columns, 245 nonzeros
# Variable types: 115 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 9162.9040475
#
# Root relaxation: objective 8.803246e+03, 65 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8803.24592    0    2 9162.90405 8803.24592  3.93%     -    0s
# H    0     0                    9040.1670165 8803.24592  2.62%     -    0s
# H    0     0                    8895.3024937 8803.24592  1.03%     -    0s
#      0     0     cutoff    0      8895.30249 8895.30249  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 2
#   Flow cover: 3
#
# Explored 1 nodes (72 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 8895.3 9040.17 9162.9
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 8.895302493750e+03, best bound 8.895302493750e+03, gap 0.0000%
# Obj: 8895.3
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xf666fc9f
# Variable types: 244 continuous, 68 integer (68 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 185 rows and 200 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 112 columns, 228 nonzeros
# Variable types: 108 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 9226.2097732
#
# Root relaxation: objective 9.080621e+03, 59 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9080.62077    0    3 9226.20977 9080.62077  1.58%     -    0s
#      0     0 9173.65714    0    2 9226.20977 9173.65714  0.57%     -    0s
# H    0     0                    9174.0626148 9173.65714  0.00%     -    0s
#
# Cutting planes:
#   Clique: 1
#   Flow cover: 3
#
# Explored 1 nodes (66 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 9174.06 9226.21
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 9.174062614827e+03, best bound 9.174062614827e+03, gap 0.0000%
# Obj: 9174.06
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x2ff68a15
# Variable types: 240 continuous, 72 integer (72 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 191 rows and 207 columns
# Presolve time: 0.00s
# Presolved: 69 rows, 105 columns, 212 nonzeros
# Variable types: 101 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 9671.8966887
#
# Root relaxation: objective 9.326454e+03, 54 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9326.45385    0    3 9671.89669 9326.45385  3.57%     -    0s
# H    0     0                    9472.6012527 9326.45385  1.54%     -    0s
#      0     0 9412.37155    0    1 9472.60125 9412.37155  0.64%     -    0s
#      0     0 9435.30467    0    4 9472.60125 9435.30467  0.39%     -    0s
#      0     0 9440.62697    0    4 9472.60125 9440.62697  0.34%     -    0s
#      0     0 9446.12293    0    3 9472.60125 9446.12293  0.28%     -    0s
#      0     0 9456.67544    0    4 9472.60125 9456.67544  0.17%     -    0s
#      0     0 9457.75547    0    4 9472.60125 9457.75547  0.16%     -    0s
#      0     0 9459.75273    0    4 9472.60125 9459.75273  0.14%     -    0s
#      0     0 9462.80414    0    4 9472.60125 9462.80414  0.10%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   MIR: 4
#   Flow cover: 3
#
# Explored 1 nodes (79 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 9472.6 9671.9
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 9.472601252728e+03, best bound 9.472601252728e+03, gap 0.0000%
# Obj: 9472.6
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xf4c6c1f8
# Variable types: 236 continuous, 76 integer (76 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 195 rows and 211 columns
# Presolve time: 0.00s
# Presolved: 65 rows, 101 columns, 200 nonzeros
# Variable types: 97 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 9992.3008636
#
# Root relaxation: objective 9.613090e+03, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9613.09008    0    2 9992.30086 9613.09008  3.80%     -    0s
# H    0     0                    9854.0305036 9613.09008  2.45%     -    0s
# H    0     0                    9692.4667075 9613.09008  0.82%     -    0s
#      0     0     cutoff    0      9692.46671 9692.46671  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 2
#   Flow cover: 3
#
# Explored 1 nodes (54 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 9692.47 9854.03 9992.3
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 9.692466707486e+03, best bound 9.692466707486e+03, gap 0.0000%
# Obj: 9692.47
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x0ab696d2
# Variable types: 232 continuous, 80 integer (80 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 202 rows and 219 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 93 columns, 181 nonzeros
# Variable types: 89 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 10018.646552
#
# Root relaxation: objective 9.907158e+03, 41 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9907.15833    0    2 10018.6466 9907.15833  1.11%     -    0s
#      0     0 9989.26570    0    3 10018.6466 9989.26570  0.29%     -    0s
#      0     0 10001.4302    0    4 10018.6466 10001.4302  0.17%     -    0s
#      0     0 10007.7373    0    1 10018.6466 10007.7373  0.11%     -    0s
#      0     0 10014.8884    0    3 10018.6466 10014.8884  0.04%     -    0s
#      0     0     cutoff    0      10018.6466 10018.6466  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Clique: 1
#   MIR: 3
#   Flow cover: 2
#
# Explored 1 nodes (56 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 10018.6
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.001864655190e+04, best bound 1.001864655190e+04, gap 0.0000%
# Obj: 10018.6
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x1a39e2d9
# Variable types: 228 continuous, 84 integer (84 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 205 rows and 222 columns
# Presolve time: 0.00s
# Presolved: 55 rows, 90 columns, 172 nonzeros
# Variable types: 86 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 10535.376618
#
# Root relaxation: objective 1.018127e+04, 39 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10181.2674    0    3 10535.3766 10181.2674  3.36%     -    0s
# H    0     0                    10339.360729 10181.2674  1.53%     -    0s
# H    0     0                    10271.001215 10181.2674  0.87%     -    0s
#      0     0 10253.5812    0    3 10271.0012 10253.5812  0.17%     -    0s
#      0     0     cutoff    0      10271.0012 10271.0012  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   MIR: 1
#   Flow cover: 5
#   Relax-and-lift: 1
#
# Explored 1 nodes (48 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 10271 10339.4 10535.4
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.027100121539e+04, best bound 1.027100121539e+04, gap 0.0000%
# Obj: 10271
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x5728e79e
# Variable types: 224 continuous, 88 integer (88 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 212 rows and 230 columns
# Presolve time: 0.00s
# Presolved: 48 rows, 82 columns, 153 nonzeros
# Variable types: 78 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 10585.495597
#
# Root relaxation: objective 1.046796e+04, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10467.9576    0    3 10585.4956 10467.9576  1.11%     -    0s
#      0     0 10551.1303    0    3 10585.4956 10551.1303  0.32%     -    0s
#      0     0 10562.1036    0    4 10585.4956 10562.1036  0.22%     -    0s
#      0     0 10573.7873    0    1 10585.4956 10573.7873  0.11%     -    0s
#      0     0 10583.1716    0    4 10585.4956 10583.1716  0.02%     -    0s
#      0     0     cutoff    0      10585.4956 10585.4956  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 1
#   Clique: 1
#   MIR: 2
#   Flow cover: 3
#
# Explored 1 nodes (61 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 10585.5
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.058549559743e+04, best bound 1.058549559743e+04, gap 0.0000%
# Obj: 10585.5
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xb89e69ef
# Variable types: 220 continuous, 92 integer (92 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 215 rows and 233 columns
# Presolve time: 0.01s
# Presolved: 45 rows, 79 columns, 144 nonzeros
# Variable types: 75 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 11093.463997
#
# Root relaxation: objective 1.079830e+04, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10798.3004    0    3 11093.4640 10798.3004  2.66%     -    0s
# H    0     0                    10924.424259 10798.3004  1.15%     -    0s
#      0     0 10864.2809    0    2 10924.4243 10864.2809  0.55%     -    0s
# H    0     0                    10896.512015 10864.2809  0.30%     -    0s
#      0     0 10865.5388    0    1 10896.5120 10865.5388  0.28%     -    0s
#      0     0 10867.0331    0    4 10896.5120 10867.0331  0.27%     -    0s
#      0     0 10875.1745    0    2 10896.5120 10875.1745  0.20%     -    0s
#      0     0     cutoff    0      10896.5120 10896.5120  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Flow cover: 5
#   Flow path: 1
#
# Explored 1 nodes (49 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 10896.5 10924.4 11093.5
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.089651201532e+04, best bound 1.089651201532e+04, gap 0.0000%
# Obj: 10896.5
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xe5df3f98
# Variable types: 216 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 219 rows and 237 columns
# Presolve time: 0.00s
# Presolved: 41 rows, 75 columns, 133 nonzeros
# Variable types: 71 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 11414.803166
#
# Root relaxation: objective 1.106675e+04, 27 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11066.7474    0    3 11414.8032 11066.7474  3.05%     -    0s
# H    0     0                    11215.959978 11066.7474  1.33%     -    0s
# H    0     0                    11215.399320 11066.7474  1.33%     -    0s
#      0     0 11142.6628    0    1 11215.3993 11142.6628  0.65%     -    0s
# H    0     0                    11145.785512 11142.6628  0.03%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   MIR: 1
#   Flow cover: 4
#
# Explored 1 nodes (33 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 11145.8 11215.4 11216 11414.8
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.114578551164e+04, best bound 1.114578551164e+04, gap 0.0000%
# Obj: 11145.8
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x0bc313d2
# Variable types: 212 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 225 rows and 244 columns
# Presolve time: 0.00s
# Presolved: 35 rows, 68 columns, 117 nonzeros
# Variable types: 64 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 11587.683824
#
# Root relaxation: objective 1.125643e+04, 24 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11256.4329    0    2 11587.6838 11256.4329  2.86%     -    0s
# H    0     0                    11404.555303 11256.4329  1.30%     -    0s
#      0     0 11338.9512    0    3 11404.5553 11338.9512  0.58%     -    0s
#      0     0 11345.0974    0    4 11404.5553 11345.0974  0.52%     -    0s
#      0     0 11347.9604    0    3 11404.5553 11347.9604  0.50%     -    0s
#      0     0 11348.4553    0    3 11404.5553 11348.4553  0.49%     -    0s
#      0     0 11355.5770    0    4 11404.5553 11355.5770  0.43%     -    0s
#      0     0 11355.7756    0    4 11404.5553 11355.7756  0.43%     -    0s
#      0     0 11355.8531    0    4 11404.5553 11355.8531  0.43%     -    0s
#      0     0 11377.3626    0    4 11404.5553 11377.3626  0.24%     -    0s
#      0     0 11377.6349    0    4 11404.5553 11377.6349  0.24%     -    0s
#      0     0 11377.8395    0    4 11404.5553 11377.8395  0.23%     -    0s
#      0     0 11377.9590    0    4 11404.5553 11377.9590  0.23%     -    0s
#      0     0 11389.2170    0    2 11404.5553 11389.2170  0.13%     -    0s
#      0     0 11389.6114    0    2 11404.5553 11389.6114  0.13%     -    0s
# *    0     0               0    11389.767777 11389.7678  0.00%     -    0s
#
# Cutting planes:
#   Cover: 1
#   MIR: 1
#   StrongCG: 1
#   Flow cover: 6
#
# Explored 1 nodes (66 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 11389.8 11587.7
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.138976777696e+04, best bound 1.138976777696e+04, gap 0.0000%
# Obj: 11389.8
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x028d6c6f
# Variable types: 208 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 228 rows and 247 columns
# Presolve time: 0.00s
# Presolved: 32 rows, 65 columns, 109 nonzeros
# Variable types: 61 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 11888.265385
#
# Root relaxation: objective 1.141520e+04, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11415.2037    0    3 11888.2654 11415.2037  3.98%     -    0s
# H    0     0                    11755.287448 11415.2037  2.89%     -    0s
# H    0     0                    11473.488462 11415.2037  0.51%     -    0s
#      0     0 11454.9778    0    3 11473.4885 11454.9778  0.16%     -    0s
#      0     0 11469.0917    0    2 11473.4885 11469.0917  0.04%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 1
#   Flow cover: 1
#
# Explored 1 nodes (30 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 11473.5 11755.3 11888.3
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.147348846154e+04, best bound 1.147348846154e+04, gap 0.0000%
# Obj: 11473.5
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x211e3bca
# Variable types: 208 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 235 rows and 254 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 58 columns, 91 nonzeros
# Variable types: 56 continuous, 2 integer (2 binary)
# Found heuristic solution: objective 11666.288462
#
# Root relaxation: objective 1.147349e+04, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# ...
# H    0     0                    10364.475000 10329.9988  0.33%     -    0s
#      0     0     cutoff    0      10364.4750 10364.4750  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 1
#   Flow cover: 5
#
# Explored 1 nodes (28 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 10364.5 10621.8
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.036447500000e+04, best bound 1.036447500000e+04, gap 0.0000%
# Obj: 10364.5
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xdf273a20
# Variable types: 208 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 198 rows and 216 columns
# Presolve time: 0.00s
# Presolved: 62 rows, 96 columns, 179 nonzeros
# Variable types: 84 continuous, 12 integer (12 binary)
# Found heuristic solution: objective 11456.911538
#
# Root relaxation: objective 1.010138e+04, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10101.3827    0   10 11456.9115 10101.3827  11.8%     -    0s
# H    0     0                    11264.511538 10101.3827  10.3%     -    0s
#      0     0 10276.0846    0   11 11264.5115 10276.0846  8.77%     -    0s
#      0     0 10333.0207    0    7 11264.5115 10333.0207  8.27%     -    0s
# H    0     0                    11151.204437 10333.0207  7.34%     -    0s
# H    0     0                    10380.080769 10333.0207  0.45%     -    0s
#      0     0 10338.1657    0    4 10380.0808 10338.1657  0.40%     -    0s
#      0     0 10338.2570    0    6 10380.0808 10338.2570  0.40%     -    0s
#      0     0 10338.3182    0    7 10380.0808 10338.3182  0.40%     -    0s
#      0     0 10338.5163    0    5 10380.0808 10338.5163  0.40%     -    0s
#      0     0 10338.9143    0    5 10380.0808 10338.9143  0.40%     -    0s
#      0     0 10338.9143    0    5 10380.0808 10338.9143  0.40%     -    0s
#      0     2 10343.4496    0    5 10380.0808 10343.4496  0.35%     -    0s
# *   10     1               2    10364.475000 10358.7282  0.06%   5.4    0s
#
# Cutting planes:
#   MIR: 3
#   Flow cover: 11
#   Flow path: 2
#
# Explored 13 nodes (151 simplex iterations) in 0.10 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 5: 10364.5 10380.1 11151.2 ... 11456.9
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.036447500000e+04, best bound 1.036447500000e+04, gap 0.0000%
# Obj: 10364.5
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x6b6f4225
# Variable types: 208 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 213 rows and 232 columns
# Presolve time: 0.00s
# Presolved: 47 rows, 80 columns, 142 nonzeros
# Variable types: 74 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 10817.576923
#
# Root relaxation: objective 1.020693e+04, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10206.9270    0    4 10817.5769 10206.9270  5.64%     -    0s
# H    0     0                    10704.511538 10206.9270  4.65%     -    0s
#      0     0 10323.8801    0    5 10704.5115 10323.8801  3.56%     -    0s
# H    0     0                    10380.930769 10323.8801  0.55%     -    0s
#      0     0 10328.5139    0    5 10380.9308 10328.5139  0.50%     -    0s
#      0     0 10341.5427    0    6 10380.9308 10341.5427  0.38%     -    0s
#      0     0 10345.7700    0    6 10380.9308 10345.7700  0.34%     -    0s
#      0     0 10353.2460    0    6 10380.9308 10353.2460  0.27%     -    0s
#      0     0 10361.9947    0    5 10380.9308 10361.9947  0.18%     -    0s
#      0     0 10362.6623    0    5 10380.9308 10362.6623  0.18%     -    0s
# *    0     0               0    10364.475000 10364.4750  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 3
#   Flow cover: 4
#   Flow path: 2
#
# Explored 1 nodes (71 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 10364.5 10380.9 10704.5 10817.6
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.036447500000e+04, best bound 1.036447500000e+04, gap 0.0000%
# Obj: 10364.5
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x1c0c01f0
# Variable types: 208 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 190 rows and 207 columns
# Presolve time: 0.00s
# Presolved: 70 rows, 105 columns, 199 nonzeros
# Variable types: 89 continuous, 16 integer (16 binary)
# Found heuristic solution: objective 12101.534615
#
# Root relaxation: objective 9.874624e+03, 50 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9874.62409    0   16 12101.5346 9874.62409  18.4%     -    0s
# H    0     0                    11913.138462 9874.62409  17.1%     -    0s
#      0     0 10212.5794    0   16 11913.1385 10212.5794  14.3%     -    0s
#      0     0 10271.8965    0   11 11913.1385 10271.8965  13.8%     -    0s
# H    0     0                    11539.858511 10271.8965  11.0%     -    0s
# H    0     0                    10514.582692 10271.8965  2.31%     -    0s
#      0     0 10273.0521    0   13 10514.5827 10273.0521  2.30%     -    0s
#      0     0 10273.1290    0   12 10514.5827 10273.1290  2.30%     -    0s
#      0     0 10276.8273    0   12 10514.5827 10276.8273  2.26%     -    0s
# H    0     0                    10451.438462 10276.8273  1.67%     -    0s
#      0     0 10280.1474    0   11 10451.4385 10280.1474  1.64%     -    0s
# H    0     0                    10380.080769 10280.1474  0.96%     -    0s
#      0     0 10280.7453    0   12 10380.0808 10280.7453  0.96%     -    0s
#      0     0 10283.3374    0   13 10380.0808 10283.3374  0.93%     -    0s
# H    0     0                    10364.475000 10283.3374  0.78%     -    0s
#      0     0 10283.5150    0   13 10364.4750 10283.5150  0.78%     -    0s
#      0     0 10285.5249    0   12 10364.4750 10285.5249  0.76%     -    0s
#      0     0 10286.0664    0   13 10364.4750 10286.0664  0.76%     -    0s
#      0     0 10288.1120    0   13 10364.4750 10288.1120  0.74%     -    0s
#      0     0 10288.3822    0   13 10364.4750 10288.3822  0.73%     -    0s
#      0     0 10288.4764    0   14 10364.4750 10288.4764  0.73%     -    0s
#      0     0 10289.8544    0   13 10364.4750 10289.8544  0.72%     -    0s
#      0     0 10290.0731    0   13 10364.4750 10290.0731  0.72%     -    0s
#      0     0 10290.0731    0   13 10364.4750 10290.0731  0.72%     -    0s
#      0     2 10292.3625    0   13 10364.4750 10292.3625  0.70%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 1
#   MIR: 9
#   Flow cover: 18
#   Flow path: 9
#
# Explored 36 nodes (426 simplex iterations) in 0.21 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 7: 10364.5 10380.1 10451.4 ... 12101.5
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.036447500000e+04, best bound 1.036447500000e+04, gap 0.0000%
# Obj: 10364.5
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0x9a9ecb1a
# Variable types: 208 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 207 rows and 222 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 90 columns, 162 nonzeros
# Variable types: 81 continuous, 9 integer (9 binary)
# Found heuristic solution: objective 10956.609615
#
# Root relaxation: objective 1.012477e+04, 39 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10124.7741    0    5 10956.6096 10124.7741  7.59%     -    0s
# H    0     0                    10600.088462 10124.7741  4.48%     -    0s
# H    0     0                    10390.953846 10124.7741  2.56%     -    0s
#      0     0 10303.3450    0    7 10390.9538 10303.3450  0.84%     -    0s
#      0     0 10337.1404    0    7 10390.9538 10337.1404  0.52%     -    0s
#      0     0 10339.1012    0    7 10390.9538 10339.1012  0.50%     -    0s
#      0     0 10340.9682    0    8 10390.9538 10340.9682  0.48%     -    0s
#      0     0 10341.2710    0    8 10390.9538 10341.2710  0.48%     -    0s
#      0     0 10341.3978    0    8 10390.9538 10341.3978  0.48%     -    0s
#      0     0 10348.5292    0    8 10390.9538 10348.5292  0.41%     -    0s
#      0     0 10348.5673    0    8 10390.9538 10348.5673  0.41%     -    0s
#      0     0 10352.4797    0    8 10390.9538 10352.4797  0.37%     -    0s
# H    0     0                    10364.475000 10352.4797  0.12%     -    0s
#      0     0 10353.4478    0    8 10364.4750 10353.4478  0.11%     -    0s
#      0     0 10354.0818    0    5 10364.4750 10354.0818  0.10%     -    0s
#      0     0 10355.2450    0    7 10364.4750 10355.2450  0.09%     -    0s
#      0     0 10355.5496    0    8 10364.4750 10355.5496  0.09%     -    0s
#      0     0 10356.0028    0    8 10364.4750 10356.0028  0.08%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   MIR: 5
#   Flow cover: 8
#
# Explored 1 nodes (95 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 10364.5 10391 10600.1 10956.6
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.036447500000e+04, best bound 1.036447500000e+04, gap 0.0000%
# Obj: 10364.5
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xdf273a20
# Variable types: 208 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 198 rows and 216 columns
# Presolve time: 0.00s
# Presolved: 62 rows, 96 columns, 179 nonzeros
# Variable types: 84 continuous, 12 integer (12 binary)
# Found heuristic solution: objective 11456.911538
#
# Root relaxation: objective 1.010138e+04, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10101.3827    0   10 11456.9115 10101.3827  11.8%     -    0s
# H    0     0                    11264.511538 10101.3827  10.3%     -    0s
#      0     0 10276.0846    0   11 11264.5115 10276.0846  8.77%     -    0s
#      0     0 10333.0207    0    7 11264.5115 10333.0207  8.27%     -    0s
# H    0     0                    11151.204437 10333.0207  7.34%     -    0s
# H    0     0                    10380.080769 10333.0207  0.45%     -    0s
#      0     0 10338.1657    0    4 10380.0808 10338.1657  0.40%     -    0s
#      0     0 10338.2570    0    6 10380.0808 10338.2570  0.40%     -    0s
#      0     0 10338.3182    0    7 10380.0808 10338.3182  0.40%     -    0s
#      0     0 10338.5163    0    5 10380.0808 10338.5163  0.40%     -    0s
#      0     0 10338.9143    0    5 10380.0808 10338.9143  0.40%     -    0s
#      0     0 10338.9143    0    5 10380.0808 10338.9143  0.40%     -    0s
#      0     2 10343.4496    0    5 10380.0808 10343.4496  0.35%     -    0s
# *   10     1               2    10364.475000 10358.7282  0.06%   5.4    0s
#
# Cutting planes:
#   MIR: 3
#   Flow cover: 11
#   Flow path: 2
#
# Explored 13 nodes (151 simplex iterations) in 0.17 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 5: 10364.5 10380.1 11151.2 ... 11456.9
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.036447500000e+04, best bound 1.036447500000e+04, gap 0.0000%
# Obj: 10364.5
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 1e-06
# Set parameter Threads to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (linux64)
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
# Optimize a model with 260 rows, 312 columns and 674 nonzeros
# Model fingerprint: 0xdf273a20
# Variable types: 208 continuous, 104 integer (104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e-01, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+02]
# Presolve removed 198 rows and 216 columns
# Presolve time: 0.00s
# Presolved: 62 rows, 96 columns, 179 nonzeros
# Variable types: 84 continuous, 12 integer (12 binary)
# Found heuristic solution: objective 11456.911538
#
# Root relaxation: objective 1.010138e+04, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10101.3827    0   10 11456.9115 10101.3827  11.8%     -    0s
# H    0     0                    11264.511538 10101.3827  10.3%     -    0s
#      0     0 10276.0846    0   11 11264.5115 10276.0846  8.77%     -    0s
#      0     0 10333.0207    0    7 11264.5115 10333.0207  8.27%     -    0s
# H    0     0                    11151.204437 10333.0207  7.34%     -    0s
# H    0     0                    10380.080769 10333.0207  0.45%     -    0s
#      0     0 10338.1657    0    4 10380.0808 10338.1657  0.40%     -    0s
#      0     0 10338.2570    0    6 10380.0808 10338.2570  0.40%     -    0s
#      0     0 10338.3182    0    7 10380.0808 10338.3182  0.40%     -    0s
#      0     0 10338.5163    0    5 10380.0808 10338.5163  0.40%     -    0s
#      0     0 10338.9143    0    5 10380.0808 10338.9143  0.40%     -    0s
#      0     0 10338.9143    0    5 10380.0808 10338.9143  0.40%     -    0s
#      0     2 10343.4496    0    5 10380.0808 10343.4496  0.35%     -    0s
# *   10     1               2    10364.475000 10358.7282  0.06%   5.4    0s
#
# Cutting planes:
#   MIR: 3
#   Flow cover: 11
#   Flow path: 2
#
# Explored 13 nodes (151 simplex iterations) in 0.14 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 5: 10364.5 10380.1 11151.2 ... 11456.9
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 1.036447500000e+04, best bound 1.036447500000e+04, gap 0.0000%
# Obj: 10364.5
