# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
form_ = "MC"

file=f"/home/jossian/repository/Mestrado/CLSP_PY/MODELO_{form_}/MODELO_{form_}_RF_OPT/RESULTADOS/clsr_{form_}_relax_and_opt_table.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['instance','rf','trf','opt','topt','time']


rf_opt_mc = table
rf_opt_mc
# Out:
#         instance       rf     trf      opt   topt    time
# 0      c52_1.txt   9796.8   6.737   9776.4  3.264  10.001
# 1      c52_2.txt  10204.6   8.280  10159.2  3.964  12.244
# 2      c52_3.txt   9413.8   6.616   9381.8  2.871   9.487
# 3      c52_4.txt  10400.2   8.298  10381.4  4.008  12.306
# 4      c52_5.txt  11243.5   6.712  11172.0  3.464  10.176
# ..           ...      ...     ...      ...    ...     ...
# 103  c52_104.txt  72897.5  14.677  72897.5  3.686  18.363
# 104  c52_105.txt  71415.8  12.770  71363.0  3.725  16.495
# 105  c52_106.txt  84083.0  16.677  83903.2  4.262  20.939
# 106  c52_107.txt  64242.8  12.129  64197.0  3.419  15.548
# 107  c52_108.txt  67209.8  14.630  67104.0  3.749  18.380
#
# [108 rows x 6 columns]

# %%
set_ = 'set01'

tab = pd.DataFrame()
for i in range(1,13):
    t = rf_opt_mc.loc[rf_opt_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set01_rf_opt_mc = tab
set01_rf_opt_mc
# Out:
#    instance            rf      trf       opt     topt      time
# MC    set01  10718.816667  6.76875  10678.45  3.29025  10.05875

# %%
set_ = 'set02'

tab = pd.DataFrame()
for i in range(13,25):
    t = rf_opt_mc.loc[rf_opt_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set02_rf_opt_mc = tab
set02_rf_opt_mc
# Out:
#    instance            rf       trf      opt   topt       time
# MC    set02  17377.058333  8.123917  17353.1  3.853  11.976833

# %%
set_ = 'set03'

tab = pd.DataFrame()
for i in range(25,37):
    t = rf_opt_mc.loc[rf_opt_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set03_rf_opt_mc = tab
set03_rf_opt_mc
# Out:
#    instance            rf       trf           opt   topt       time
# MC    set03  48375.308333  9.822583  48312.366667  4.229  14.051667

# %%
set_ = 'set04'

tab = pd.DataFrame()
for i in range(37,49):
    t = rf_opt_mc.loc[rf_opt_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set04_rf_opt_mc = tab
set04_rf_opt_mc
# Out:
#    instance       rf       trf           opt      topt       time
# MC    set04  15032.0  6.987833  14963.783333  3.376167  10.363833

# %%
set_ = 'set05'

tab = pd.DataFrame()
for i in range(49,61):
    t = rf_opt_mc.loc[rf_opt_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set05_rf_opt_mc = tab
set05_rf_opt_mc
# Out:
#    instance            rf       trf        opt     topt       time
# MC    set05  22049.716667  9.379833  21968.925  3.94725  13.326917

# %%
set_ = 'set06'

tab = pd.DataFrame()
for i in range(61,73):
    t = rf_opt_mc.loc[rf_opt_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set06_rf_opt_mc = tab
set06_rf_opt_mc
# Out:
#    instance         rf      trf           opt      topt       time
# MC    set06  53233.225  12.2215  53137.708333  4.363167  16.584583

# %%
set_ = 'set07'

tab = pd.DataFrame()
for i in range(73,85):
    t = rf_opt_mc.loc[rf_opt_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set07_rf_opt_mc = tab
set07_rf_opt_mc
# Out:
#    instance         rf      trf        opt      topt    time
# MC    set07  33013.075  5.87125  28002.125  2.759083  8.6305

# %%
set_ = 'set08'

tab = pd.DataFrame()
for i in range(95,97):
    t = rf_opt_mc.loc[rf_opt_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set08_rf_opt_mc = tab
set08_rf_opt_mc
# Out:
#    instance       rf     trf      opt    topt     time
# MC    set08  51671.5  9.0575  43365.9  3.6485  12.7055

# %%
set_ = 'set09'

tab = pd.DataFrame()
for i in range(97,109):
    t = rf_opt_mc.loc[rf_opt_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set09_rf_opt_mc = tab
set09_rf_opt_mc
# Out:
#    instance            rf        trf           opt      topt       time
# MC    set09  73353.191667  14.183417  73182.041667  3.841167  18.024583

# %%
res_rf_opt_mc = pd.DataFrame()
res_rf_opt_mc = pd.concat([res_rf_opt_mc,set01_rf_opt_mc], ignore_index= True)
res_rf_opt_mc = pd.concat([res_rf_opt_mc,set02_rf_opt_mc], ignore_index= True)
res_rf_opt_mc = pd.concat([res_rf_opt_mc,set03_rf_opt_mc], ignore_index= True)
res_rf_opt_mc = pd.concat([res_rf_opt_mc,set04_rf_opt_mc], ignore_index= True)
res_rf_opt_mc = pd.concat([res_rf_opt_mc,set05_rf_opt_mc], ignore_index= True)
res_rf_opt_mc = pd.concat([res_rf_opt_mc,set06_rf_opt_mc], ignore_index= True)
res_rf_opt_mc = pd.concat([res_rf_opt_mc,set07_rf_opt_mc], ignore_index= True)
res_rf_opt_mc = pd.concat([res_rf_opt_mc,set08_rf_opt_mc], ignore_index= True)
res_rf_opt_mc = pd.concat([res_rf_opt_mc,set09_rf_opt_mc], ignore_index= True)
res_rf_opt_mc
# Out:
#   instance            rf        trf           opt      topt       time
# 0    set01  10718.816667   6.768750  10678.450000  3.290250  10.058750
# 1    set02  17377.058333   8.123917  17353.100000  3.853000  11.976833
# 2    set03  48375.308333   9.822583  48312.366667  4.229000  14.051667
# 3    set04  15032.000000   6.987833  14963.783333  3.376167  10.363833
# 4    set05  22049.716667   9.379833  21968.925000  3.947250  13.326917
# 5    set06  53233.225000  12.221500  53137.708333  4.363167  16.584583
# 6    set07  33013.075000   5.871250  28002.125000  2.759083   8.630500
# 7    set08  51671.500000   9.057500  43365.900000  3.648500  12.705500
# 8    set09  73353.191667  14.183417  73182.041667  3.841167  18.024583

# %%
tab = pd.DataFrame({
    'instance':f'res_rf_opt_mc',
    'rf':res_rf_opt_mc['rf'].mean(),
    'trf':res_rf_opt_mc['trf'].mean(),
    'opt':res_rf_opt_mc['opt'].mean(),
    'topt':res_rf_opt_mc['topt'].mean(),
    'time':res_rf_opt_mc['time'].mean(),
    },index=[f'res_rf_opt_mc']
)

res_rf_opt_mc = pd.concat([res_rf_opt_mc, tab], ignore_index=True)
res_rf_opt_mc

print(res_rf_opt_mc[['instance','rf','trf','opt','topt','time']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# instance & rf & trf & opt & topt & time \\
# \midrule
# set01 & 10718.82 & 6.77 & 10678.45 & 3.29 & 10.06 \\
# set02 & 17377.06 & 8.12 & 17353.10 & 3.85 & 11.98 \\
# set03 & 48375.31 & 9.82 & 48312.37 & 4.23 & 14.05 \\
# set04 & 15032.00 & 6.99 & 14963.78 & 3.38 & 10.36 \\
# set05 & 22049.72 & 9.38 & 21968.93 & 3.95 & 13.33 \\
# set06 & 53233.23 & 12.22 & 53137.71 & 4.36 & 16.58 \\
# set07 & 33013.08 & 5.87 & 28002.13 & 2.76 & 8.63 \\
# set08 & 51671.50 & 9.06 & 43365.90 & 3.65 & 12.71 \\
# set09 & 73353.19 & 14.18 & 73182.04 & 3.84 & 18.02 \\
# res_rf_opt_mc & 36091.54 & 9.16 & 34551.60 & 3.70 & 12.86 \\
# res_rf_opt_mc & 36091.54 & 9.16 & 34551.60 & 3.70 & 12.86 \\
# \bottomrule
# \end{tabular}

# %%
form_ = "SP"

file=f"/home/jossian/repository/Mestrado/CLSP_PY/MODELO_{form_}/MODELO_{form_}_RF_OPT/RESULTADOS/clsr_{form_}_relax_and_opt_table.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['instance','rf','trf','opt','topt','time']


rf_opt_sp = table
rf_opt_sp
# Out:
#         instance       rf     trf      opt   topt    time
# 0      c52_1.txt   9796.8   4.276   9776.4  2.764   7.040
# 1      c52_2.txt  10204.6   5.610  10159.2  3.312   8.922
# 2      c52_3.txt   9413.8   3.908   9381.8  2.625   6.533
# 3      c52_4.txt  10400.2   5.415  10381.4  3.638   9.053
# 4      c52_5.txt  11243.5   4.512  11172.0  3.093   7.605
# ..           ...      ...     ...      ...    ...     ...
# 103  c52_104.txt  72897.5  20.317  72897.5  4.135  24.452
# 104  c52_105.txt  71415.8  14.641  71363.0  3.877  18.518
# 105  c52_106.txt  84083.0  24.909  83903.2  5.707  30.616
# 106  c52_107.txt  64242.8  11.855  64197.0  3.125  14.980
# 107  c52_108.txt  67209.8  15.973  67104.0  3.680  19.654
#
# [108 rows x 6 columns]

# %%
set_ = 'set01'

tab = pd.DataFrame()
for i in range(1,13):
    t = rf_opt_sp.loc[rf_opt_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set01_rf_opt_sp = tab
set01_rf_opt_sp
# Out:
#    instance            rf       trf       opt      topt      time
# SP    set01  10718.816667  4.126333  10678.45  2.865083  6.991583

# %%
set_ = 'set02'

tab = pd.DataFrame()
for i in range(13,25):
    t = rf_opt_sp.loc[rf_opt_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set02_rf_opt_sp = tab
set02_rf_opt_sp
# Out:
#    instance            rf       trf           opt     topt      time
# SP    set02  17377.058333  5.895333  17353.099917  3.50275  9.398167

# %%
set_ = 'set03'

tab = pd.DataFrame()
for i in range(25,37):
    t = rf_opt_sp.loc[rf_opt_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set03_rf_opt_sp = tab
set03_rf_opt_sp
# Out:
#    instance            rf       trf           opt     topt       time
# SP    set03  48375.308333  9.218417  48312.366667  4.55025  13.768833

# %%
set_ = 'set04'

tab = pd.DataFrame()
for i in range(37,49):
    t = rf_opt_sp.loc[rf_opt_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set04_rf_opt_sp = tab
set04_rf_opt_sp
# Out:
#    instance       rf       trf           opt     topt      time
# SP    set04  15032.0  4.950583  14963.783333  2.83175  7.782333

# %%
set_ = 'set05'

tab = pd.DataFrame()
for i in range(49,61):
    t = rf_opt_sp.loc[rf_opt_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set05_rf_opt_sp = tab
set05_rf_opt_sp
# Out:
#    instance            rf       trf        opt      topt       time
# SP    set05  22049.716667  7.609833  21968.925  3.473333  11.083417

# %%
set_ = 'set06'

tab = pd.DataFrame()
for i in range(61,73):
    t = rf_opt_sp.loc[rf_opt_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set06_rf_opt_sp = tab
set06_rf_opt_sp
# Out:
#    instance         rf     trf           opt      topt       time
# SP    set06  53233.225  10.685  53137.708333  4.281833  14.967083

# %%
set_ = 'set07'

tab = pd.DataFrame()
for i in range(73,85):
    t = rf_opt_sp.loc[rf_opt_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set07_rf_opt_sp = tab
set07_rf_opt_sp
# Out:
#    instance         rf      trf           opt      topt     time
# SP    set07  33013.075  4.96725  28003.458333  2.838417  7.80575

# %%
set_ = 'set08'

tab = pd.DataFrame()
for i in range(85,97):
    t = rf_opt_sp.loc[rf_opt_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set08_rf_opt_sp = tab
set08_rf_opt_sp
# Out:
#    instance            rf       trf           opt      topt       time
# SP    set08  42352.816667  6.972083  37289.458333  3.255333  10.227417

# %%
set_ = 'set09'

tab = pd.DataFrame()
for i in range(97,109):
    t = rf_opt_sp.loc[rf_opt_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set09_rf_opt_sp = tab
set09_rf_opt_sp
# Out:
#    instance            rf        trf           opt     topt       time
# SP    set09  73353.191667  18.787333  73182.041667  4.27675  23.064167

# %%
res_rf_opt_sp = pd.DataFrame()
res_rf_opt_sp = pd.concat([res_rf_opt_sp,set01_rf_opt_sp], ignore_index= True)
res_rf_opt_sp = pd.concat([res_rf_opt_sp,set02_rf_opt_sp], ignore_index= True)
res_rf_opt_sp = pd.concat([res_rf_opt_sp,set03_rf_opt_sp], ignore_index= True)
res_rf_opt_sp = pd.concat([res_rf_opt_sp,set04_rf_opt_sp], ignore_index= True)
res_rf_opt_sp = pd.concat([res_rf_opt_sp,set05_rf_opt_sp], ignore_index= True)
res_rf_opt_sp = pd.concat([res_rf_opt_sp,set06_rf_opt_sp], ignore_index= True)
res_rf_opt_sp = pd.concat([res_rf_opt_sp,set07_rf_opt_sp], ignore_index= True)
res_rf_opt_sp = pd.concat([res_rf_opt_sp,set08_rf_opt_sp], ignore_index= True)
res_rf_opt_sp = pd.concat([res_rf_opt_sp,set09_rf_opt_sp], ignore_index= True)
res_rf_opt_sp
# Out:
#   instance            rf        trf           opt      topt       time
# 0    set01  10718.816667   4.126333  10678.450000  2.865083   6.991583
# 1    set02  17377.058333   5.895333  17353.099917  3.502750   9.398167
# 2    set03  48375.308333   9.218417  48312.366667  4.550250  13.768833
# 3    set04  15032.000000   4.950583  14963.783333  2.831750   7.782333
# 4    set05  22049.716667   7.609833  21968.925000  3.473333  11.083417
# 5    set06  53233.225000  10.685000  53137.708333  4.281833  14.967083
# 6    set07  33013.075000   4.967250  28003.458333  2.838417   7.805750
# 7    set08  42352.816667   6.972083  37289.458333  3.255333  10.227417
# 8    set09  73353.191667  18.787333  73182.041667  4.276750  23.064167

# %%
tab = pd.DataFrame({
    'instance':f'res_rf_opt_sp',
    'rf':res_rf_opt_sp['rf'].mean(),
    'trf':res_rf_opt_sp['trf'].mean(),
    'opt':res_rf_opt_sp['opt'].mean(),
    'topt':res_rf_opt_sp['topt'].mean(),
    'time':res_rf_opt_sp['time'].mean(),
    },index=[f'res_rf_opt_sp']
)

res_rf_opt_sp = pd.concat([res_rf_opt_sp, tab], ignore_index=True)
res_rf_opt_sp

print(res_rf_opt_sp[['instance','rf','trf','opt','topt','time']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# instance & rf & trf & opt & topt & time \\
# \midrule
# set01 & 10718.82 & 4.13 & 10678.45 & 2.87 & 6.99 \\
# set02 & 17377.06 & 5.90 & 17353.10 & 3.50 & 9.40 \\
# set03 & 48375.31 & 9.22 & 48312.37 & 4.55 & 13.77 \\
# set04 & 15032.00 & 4.95 & 14963.78 & 2.83 & 7.78 \\
# set05 & 22049.72 & 7.61 & 21968.93 & 3.47 & 11.08 \\
# set06 & 53233.23 & 10.68 & 53137.71 & 4.28 & 14.97 \\
# set07 & 33013.08 & 4.97 & 28003.46 & 2.84 & 7.81 \\
# set08 & 42352.82 & 6.97 & 37289.46 & 3.26 & 10.23 \\
# set09 & 73353.19 & 18.79 & 73182.04 & 4.28 & 23.06 \\
# res_rf_opt_sp & 35056.13 & 8.13 & 33876.59 & 3.54 & 11.68 \\
# \bottomrule
# \end{tabular}

# %%
form_ = "STD"

file=f"/home/jossian/repository/Mestrado/CLSP_PY/MODELO_{form_}/MODELO_{form_}_RF_OPT/RESULTADOS/clsr_{form_}_relax_and_opt_table.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['instance','rf','trf','opt','topt','time']


rf_opt_std = table
rf_opt_std
# Out:
#         instance       rf    trf      opt   topt   time
# 0      c52_1.txt   9883.2  0.456   9883.2  0.346  0.801
# 1      c52_2.txt  10235.8  0.539  10181.0  0.434  0.972
# 2      c52_3.txt   9442.8  0.485   9404.6  0.301  0.786
# 3      c52_4.txt  10451.2  0.558  10418.6  0.403  0.961
# 4      c52_5.txt  11201.0  0.580  11164.5  0.383  0.963
# ..           ...      ...    ...      ...    ...    ...
# 103  c52_104.txt  81737.0  0.456  78664.0  0.332  0.788
# 104  c52_105.txt  76685.8  0.300  74869.0  0.268  0.569
# 105  c52_106.txt  90922.6  0.299  86501.6  0.223  0.522
# 106  c52_107.txt  67157.2  0.263  64972.4  0.200  0.463
# 107  c52_108.txt  68544.8  0.346  66727.6  0.211  0.556
#
# [108 rows x 6 columns]

# %%
set_ = 'set01'

tab = pd.DataFrame()
for i in range(1,13):
    t = rf_opt_std.loc[rf_opt_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set01_rf_opt_std = tab
set01_rf_opt_std
# Out:
#     instance        rf       trf        opt      topt      time
# STD    set01  10748.35  0.530417  10712.275  0.380833  0.911167

# %%
set_ = 'set02'

tab = pd.DataFrame()
for i in range(13,25):
    t = rf_opt_std.loc[rf_opt_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set02_rf_opt_std = tab
set02_rf_opt_std
# Out:
#     instance       rf       trf           opt      topt     time
# STD    set02  17384.5  0.572583  17327.008333  0.382583  0.95525

# %%
set_ = 'set03'

tab = pd.DataFrame()
for i in range(25,37):
    t = rf_opt_std.loc[rf_opt_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set03_rf_opt_std = tab
set03_rf_opt_std
# Out:
#     instance         rf      trf           opt      topt   time
# STD    set03  48396.575  0.55625  48316.116667  0.364833  0.921

# %%
set_ = 'set04'

tab = pd.DataFrame()
for i in range(37,49):
    t = rf_opt_std.loc[rf_opt_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set04_rf_opt_std = tab
set04_rf_opt_std
# Out:
#     instance            rf      trf           opt     topt     time
# STD    set04  15608.541667  0.37025  15053.383333  0.28675  0.65675

# %%
set_ = 'set05'

tab = pd.DataFrame()
for i in range(49,61):
    t = rf_opt_std.loc[rf_opt_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set05_rf_opt_std = tab
set05_rf_opt_std
# Out:
#     instance        rf       trf           opt   topt     time
# STD    set05  22737.25  0.419667  22322.841667  0.302  0.72175

# %%
set_ = 'set06'

tab = pd.DataFrame()
for i in range(61,73):
    t = rf_opt_std.loc[rf_opt_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set06_rf_opt_std = tab
set06_rf_opt_std
# Out:
#     instance            rf       trf      opt      topt      time
# STD    set06  53435.591667  0.414833  53111.9  0.285083  0.699917

# %%
set_ = 'set07'

tab = pd.DataFrame()
for i in range(73,85):
    t = rf_opt_std.loc[rf_opt_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set07_rf_opt_std = tab
set07_rf_opt_std
# Out:
#     instance            rf       trf        opt      topt      time
# STD    set07  32253.366667  0.227917  27976.775  0.210417  0.438417

# %%
set_ = 'set08'

tab = pd.DataFrame()
for i in range(85,97):
    t = rf_opt_std.loc[rf_opt_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set08_rf_opt_std = tab
set08_rf_opt_std
# Out:
#     instance       rf       trf           opt      topt      time
# STD    set08  41857.8  0.246167  37574.291667  0.194083  0.440083

# %%
set_ = 'set09'

tab = pd.DataFrame()
for i in range(97,108):
    t = rf_opt_std.loc[rf_opt_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'rf':tab['rf'].mean(),
    'trf':tab['trf'].mean(),
    'opt':tab['opt'].mean(),
    'topt':tab['topt'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set09_rf_opt_std = tab
set09_rf_opt_std
# Out:
#     instance       rf    trf           opt      topt   time
# STD    set09  80114.3  0.329  78116.327273  0.218636  0.548

# %%
res_rf_opt_std = pd.DataFrame()
res_rf_opt_std = pd.concat([res_rf_opt_std,set01_rf_opt_std], ignore_index= True)
res_rf_opt_std = pd.concat([res_rf_opt_std,set02_rf_opt_std], ignore_index= True)
res_rf_opt_std = pd.concat([res_rf_opt_std,set03_rf_opt_std], ignore_index= True)
res_rf_opt_std = pd.concat([res_rf_opt_std,set04_rf_opt_std], ignore_index= True)
res_rf_opt_std = pd.concat([res_rf_opt_std,set05_rf_opt_std], ignore_index= True)
res_rf_opt_std = pd.concat([res_rf_opt_std,set06_rf_opt_std], ignore_index= True)
res_rf_opt_std = pd.concat([res_rf_opt_std,set07_rf_opt_std], ignore_index= True)
res_rf_opt_std = pd.concat([res_rf_opt_std,set08_rf_opt_std], ignore_index= True)
res_rf_opt_std = pd.concat([res_rf_opt_std,set09_rf_opt_std], ignore_index= True)
res_rf_opt_std
# Out:
#   instance            rf       trf           opt      topt      time
# 0    set01  10748.350000  0.530417  10712.275000  0.380833  0.911167
# 1    set02  17384.500000  0.572583  17327.008333  0.382583  0.955250
# 2    set03  48396.575000  0.556250  48316.116667  0.364833  0.921000
# 3    set04  15608.541667  0.370250  15053.383333  0.286750  0.656750
# 4    set05  22737.250000  0.419667  22322.841667  0.302000  0.721750
# 5    set06  53435.591667  0.414833  53111.900000  0.285083  0.699917
# 6    set07  32253.366667  0.227917  27976.775000  0.210417  0.438417
# 7    set08  41857.800000  0.246167  37574.291667  0.194083  0.440083
# 8    set09  80114.300000  0.329000  78116.327273  0.218636  0.548000

# %%
tab = pd.DataFrame({
    'instance':f'res_rf_opt_std',
    'rf':res_rf_opt_std['rf'].mean(),
    'trf':res_rf_opt_std['trf'].mean(),
    'opt':res_rf_opt_std['opt'].mean(),
    'topt':res_rf_opt_std['topt'].mean(),
    'time':res_rf_opt_std['time'].mean(),
    },index=[f'res_rf_opt_std']
)

res_rf_opt_std = pd.concat([res_rf_opt_std, tab], ignore_index=True)
res_rf_opt_std

print(res_rf_opt_std[['instance','rf','trf','opt','topt','time']].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# instance & rf & trf & opt & topt & time \\
# \midrule
# set01 & 10748.35 & 0.53 & 10712.27 & 0.38 & 0.91 \\
# set02 & 17384.50 & 0.57 & 17327.01 & 0.38 & 0.96 \\
# set03 & 48396.58 & 0.56 & 48316.12 & 0.36 & 0.92 \\
# set04 & 15608.54 & 0.37 & 15053.38 & 0.29 & 0.66 \\
# set05 & 22737.25 & 0.42 & 22322.84 & 0.30 & 0.72 \\
# set06 & 53435.59 & 0.41 & 53111.90 & 0.29 & 0.70 \\
# set07 & 32253.37 & 0.23 & 27976.77 & 0.21 & 0.44 \\
# set08 & 41857.80 & 0.25 & 37574.29 & 0.19 & 0.44 \\
# set09 & 80114.30 & 0.33 & 78116.33 & 0.22 & 0.55 \\
# res_rf_opt_std & 35837.36 & 0.41 & 34501.21 & 0.29 & 0.70 \\
# \bottomrule
# \end{tabular}
