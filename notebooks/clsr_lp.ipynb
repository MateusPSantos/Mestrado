# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
form_ = "mc"
mip_="lp"

file=f"/home/jossian/repository/Mestrado/CLSP_PY/MODELO_MC/MODELO_MC_ORIGINAL/RESULTADOS/clsr_{form_}_{mip_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['instance','lb','time']


lp_mc = table
#lp_mc

# %%
set_ = 'set01'

tab = pd.DataFrame()
for i in range(1,13):
    t = lp_mc.loc[lp_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set01_lp_mc = tab
#set01_lp_mc

# %%
set_ = 'set02'

tab = pd.DataFrame()
for i in range(13,25):
    t = lp_mc.loc[lp_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set02_lp_mc = tab
#set02_lp_mc

# %%
set_ = 'set03'

tab = pd.DataFrame()
for i in range(25,37):
    t = lp_mc.loc[lp_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set03_lp_mc = tab
#set03_lp_mc

# %%
set_ = 'set04'

tab = pd.DataFrame()
for i in range(37,49):
    t = lp_mc.loc[lp_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set04_lp_mc = tab
#set04_lp_mc

# %%
set_ = 'set05'

tab = pd.DataFrame()
for i in range(49,61):
    t = lp_mc.loc[lp_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set05_lp_mc = tab
#set05_lp_mc

# %%
set_ = 'set06'

tab = pd.DataFrame()
for i in range(61,73):
    t = lp_mc.loc[lp_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set06_lp_mc = tab
#set06_lp_mc

# %%
set_ = 'set07'

tab = pd.DataFrame()
for i in range(73,85):
    t = lp_mc.loc[lp_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set07_lp_mc = tab
#set07_lp_mc

# %%
set_ = 'set08'

tab = pd.DataFrame()
for i in range(85,97):
    t = lp_mc.loc[lp_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set08_lp_mc = tab
#set08_lp_mc

# %%
set_ = 'set09'

tab = pd.DataFrame()
for i in range(97,109):
    t = lp_mc.loc[lp_mc['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set09_lp_mc = tab
#set09_lp_mc

# %%
form_ = "sp"
mip_="lp"

file=f"/home/jossian/repository/Mestrado/CLSP_PY/MODELO_SP/MODELO_SP_ORIGINAL/RESULTADOS/clsr_{form_}_{mip_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['instance','lb','time']


lp_sp = table
#lp_sp

# %%
set_ = 'set01'

tab = pd.DataFrame()
for i in range(1,13):
    t = lp_sp.loc[lp_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set01_lp_sp = tab
#set01_lp_sp

# %%
set_ = 'set02'

tab = pd.DataFrame()
for i in range(13,25):
    t = lp_sp.loc[lp_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set02_lp_sp = tab
#set02_lp_sp

# %%
set_ = 'set03'

tab = pd.DataFrame()
for i in range(25,37):
    t = lp_sp.loc[lp_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set03_lp_sp = tab
#set03_lp_sp

# %%
set_ = 'set04'

tab = pd.DataFrame()
for i in range(37,49):
    t = lp_sp.loc[lp_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set04_lp_sp = tab
#set04_lp_sp

# %%
set_ = 'set05'

tab = pd.DataFrame()
for i in range(49,61):
    t = lp_sp.loc[lp_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set05_lp_sp = tab
#set05_lp_sp

# %%
set_ = 'set06'

tab = pd.DataFrame()
for i in range(61,73):
    t = lp_sp.loc[lp_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set06_lp_sp = tab
#set06_lp_sp

# %%
set_ = 'set07'

tab = pd.DataFrame()
for i in range(73,85):
    t = lp_sp.loc[lp_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set07_lp_sp = tab
#set07_lp_sp

# %%
set_ = 'set08'

tab = pd.DataFrame()
for i in range(85,97):
    t = lp_sp.loc[lp_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set08_lp_sp = tab
#set08_lp_sp

# %%
set_ = 'set09'

tab = pd.DataFrame()
for i in range(97,109):
    t = lp_sp.loc[lp_sp['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set09_lp_sp = tab
#set09_lp_sp

# %%
form_ = "std"
mip_="lp"

file=f"/home/jossian/repository/Mestrado/CLSP_PY/MODELO_STD/MODELO_STD_ORIGINAL/RESULTADOS/clsr_{form_}_{mip_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['instance','lb','time']


lp_std = table
#lp_std

# %%
set_ = 'set01'

tab = pd.DataFrame()
for i in range(1,13):
    t = lp_std.loc[lp_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set01_lp_std = tab
#set01_lp_std

# %%
set_ = 'set02'

tab = pd.DataFrame()
for i in range(13,25):
    t = lp_std.loc[lp_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set02_lp_std = tab
#set02_lp_std

# %%
set_ = 'set03'

tab = pd.DataFrame()
for i in range(25,37):
    t = lp_std.loc[lp_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set03_lp_std = tab
#set03_lp_std

# %%
set_ = 'set04'

tab = pd.DataFrame()
for i in range(37,49):
    t = lp_std.loc[lp_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set04_lp_std = tab
#set04_lp_std

# %%
set_ = 'set05'

tab = pd.DataFrame()
for i in range(49,61):
    t = lp_std.loc[lp_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set05_lp_std = tab
#set05_lp_std

# %%
set_ = 'set06'

tab = pd.DataFrame()
for i in range(61,73):
    t = lp_std.loc[lp_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set06_lp_std = tab
#set06_lp_std

# %%
set_ = 'set07'

tab = pd.DataFrame()
for i in range(73,85):
    t = lp_std.loc[lp_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set07_lp_std = tab
#set07_lp_std

# %%
set_ = 'set08'

tab = pd.DataFrame()
for i in range(85,97):
    t = lp_std.loc[lp_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set08_lp_std = tab
#set08_lp_std

# %%
set_ = 'set09'

tab = pd.DataFrame()
for i in range(97,109):
    t = lp_std.loc[lp_std['instance'] == f'c52_{i}.txt']
    tab = pd.concat([tab,t])

tab = pd.DataFrame({
    'instance':f'{set_}',
    'lb':tab['lb'].mean(),
    'time':tab['time'].mean(),
    },index=[f'{form_}']
)

set09_lp_std = tab
#set09_lp_std

# %%
res_lp_mc = pd.DataFrame()
res_lp_mc = pd.concat([res_lp_mc,set01_lp_mc], ignore_index= True)
res_lp_mc = pd.concat([res_lp_mc,set02_lp_mc], ignore_index= True)
res_lp_mc = pd.concat([res_lp_mc,set03_lp_mc], ignore_index= True)
res_lp_mc = pd.concat([res_lp_mc,set04_lp_mc], ignore_index= True)
res_lp_mc = pd.concat([res_lp_mc,set05_lp_mc], ignore_index= True)
res_lp_mc = pd.concat([res_lp_mc,set06_lp_mc], ignore_index= True)
res_lp_mc = pd.concat([res_lp_mc,set07_lp_mc], ignore_index= True)
res_lp_mc = pd.concat([res_lp_mc,set08_lp_mc], ignore_index= True)
res_lp_mc = pd.concat([res_lp_mc,set09_lp_mc], ignore_index= True)
#res_lp_mc

# %%
res_lp_sp = pd.DataFrame()
res_lp_sp = pd.concat([res_lp_sp,set01_lp_sp], ignore_index= True)
res_lp_sp = pd.concat([res_lp_sp,set02_lp_sp], ignore_index= True)
res_lp_sp = pd.concat([res_lp_sp,set03_lp_sp], ignore_index= True)
res_lp_sp = pd.concat([res_lp_sp,set04_lp_sp], ignore_index= True)
res_lp_sp = pd.concat([res_lp_sp,set05_lp_sp], ignore_index= True)
res_lp_sp = pd.concat([res_lp_sp,set06_lp_sp], ignore_index= True)
res_lp_sp = pd.concat([res_lp_sp,set07_lp_sp], ignore_index= True)
res_lp_sp = pd.concat([res_lp_sp,set08_lp_sp], ignore_index= True)
res_lp_sp = pd.concat([res_lp_sp,set09_lp_sp], ignore_index= True)
#res_lp_sp

# %%
res_lp_std = pd.DataFrame()
res_lp_std = pd.concat([res_lp_std,set01_lp_std], ignore_index= True)
res_lp_std = pd.concat([res_lp_std,set02_lp_std], ignore_index= True)
res_lp_std = pd.concat([res_lp_std,set03_lp_std], ignore_index= True)
res_lp_std = pd.concat([res_lp_std,set04_lp_std], ignore_index= True)
res_lp_std = pd.concat([res_lp_std,set05_lp_std], ignore_index= True)
res_lp_std = pd.concat([res_lp_std,set06_lp_std], ignore_index= True)
res_lp_std = pd.concat([res_lp_std,set07_lp_std], ignore_index= True)
res_lp_std = pd.concat([res_lp_std,set08_lp_std], ignore_index= True)
res_lp_std = pd.concat([res_lp_std,set09_lp_std], ignore_index= True)
#res_lp_std

# %%
tab = pd.DataFrame({
    'instance':f'res_lp_mc',
    'lb':res_lp_mc['lb'].mean(),
    'time':res_lp_mc['time'].mean(),
    },index=[f'res_lp_mc']
)

res_lp_mc = pd.concat([res_lp_mc, tab], ignore_index=True)
#res_lp_mc

#print(res_lp_mc[['instance','lb','time']].to_latex(index=False,float_format="%.2f"))

# %%
tab = pd.DataFrame({
    'instance':f'res_lp_sp',
    'lb':res_lp_sp['lb'].mean(),
    'time':res_lp_sp['time'].mean(),
    },index=[f'res_lp_sp']
)

res_lp_sp = pd.concat([res_lp_sp, tab], ignore_index=True)
#res_lp_sp

#print(res_lp_sp[['instance','lb','time']].to_latex(index=False,float_format="%.2f"))

# %%
tab = pd.DataFrame({
    'instance':f'res_lp_std',
    'lb':res_lp_std['lb'].mean(),
    'time':res_lp_std['time'].mean(),
    },index=[f'res_lp_std']
)

res_lp_std = pd.concat([res_lp_std, tab], ignore_index=True)
#res_lp_std

#print(res_lp_std[['instance','lb','time']].to_latex(index=False,float_format="%.2f"))

# %%
lp = pd.DataFrame()
lp = pd.merge(res_lp_mc, res_lp_sp, on='instance')
lp = pd.merge(lp, res_lp_std, on='instance')
lp.columns = ['instance','lb_mc','time_mc','lb_sp','time_sp','lb_std','time_std']
#lp[["instance","lb_mc","lb_sp","lb_std"]]

# %%
print(lp[["instance","lb_mc","lb_sp","lb_std"]].to_latex(index=False,float_format="%.2f"))
# Out:
# \begin{tabular}{lrrr}
# \toprule
# instance & lb_mc & lb_sp & lb_std \\
# \midrule
# set01 & 9383.55 & 9383.55 & 6719.68 \\
# set02 & 13162.74 & 13162.74 & 13006.09 \\
# set03 & 24088.93 & 24088.93 & 42934.92 \\
# set04 & 12675.68 & 12675.68 & 10762.62 \\
# set05 & 16635.16 & 16635.16 & 17152.73 \\
# set06 & 28066.33 & 28066.33 & 47130.63 \\
# set07 & 20322.81 & 20322.81 & 24243.73 \\
# set08 & 24791.74 & 24791.74 & 32937.86 \\
# set09 & 37808.37 & 37808.37 & 67057.21 \\
# \bottomrule
# \end{tabular}
